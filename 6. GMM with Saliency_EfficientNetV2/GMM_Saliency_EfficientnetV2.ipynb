# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import pandas as pd
import numpy as np
from sklearn.metrics import matthews_corrcoef, roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, f1_score, auc, confusion_matrix, ConfusionMatrixDisplay
import datetime
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_dir = 'data/gmm_saliency/train'
val_dir = 'data/gmm_saliency/validation'
test_dir = 'data/gmm_saliency/testing'

# %%
train_datagen = ImageDataGenerator( 
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True,
    preprocessing_function=preprocess_input
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Generator for training
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    shuffle=True,
    class_mode='binary'  # Ensure binary class mode
)

# Generator for validation
validation_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    shuffle=True,  # Shuffling is okay for validation
    class_mode='binary'
)

# Generator for testing
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    shuffle=False,
    class_mode='binary'  # Testing labels are also binary
)
# Out:
# Found 22046 images belonging to 2 classes.
# Found 4134 images belonging to 2 classes.
# Found 1378 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}

# %%
# Load the base model MobileNetV3Large
base_model = EfficientNetV2S(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze the base model

# Create the model using Sequential
EfficientNetV2_model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    BatchNormalization(),  # Stabilize training
    Dropout(0.1),  # Increase dropout
    Dense(256, activation='relu'),
    BatchNormalization(),  # Stabilize training
    Dropout(0.1),
    Dense(1, activation='sigmoid')   # Output layer
])

# Compile the model with a learning rate of 0.01
EfficientNetV2_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
# Update the filepath to use the .keras extension
model_checkpoint_EfficientNetV2 = ModelCheckpoint(
    filepath='best_gmm_saliency_efficientnet/best_EfficientNetV2_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=2
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Hentikan jika tidak ada perbaikan setelah 10 epoch
    restore_best_weights=True,
    verbose=2
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,  # Kurangi learning rate menjadi setengah
    patience=5,  # Setelah 5 epoch tanpa perbaikan
    min_lr=1e-7,  # Batas minimum learning rate
    verbose=2
)

# Tambahkan ke daftar callback
callbacks_EfficientNetV2L = [model_checkpoint_EfficientNetV2, early_stopping, reduce_lr]

# %%
history_EfficientNetV2 = EfficientNetV2_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=50,
    callbacks=callbacks_EfficientNetV2L
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 345/345 [==============================] - ETA: 0s - loss: 0.4185 - accuracy: 0.8174
# Epoch 1: val_loss improved from inf to 0.26287, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 464s 1s/step - loss: 0.4185 - accuracy: 0.8174 - val_loss: 0.2629 - val_accuracy: 0.8957 - lr: 1.0000e-04
# Epoch 2/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3496 - accuracy: 0.8514
# Epoch 2: val_loss improved from 0.26287 to 0.24988, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 415s 1s/step - loss: 0.3496 - accuracy: 0.8514 - val_loss: 0.2499 - val_accuracy: 0.8979 - lr: 1.0000e-04
# Epoch 3/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8592
# Epoch 3: val_loss did not improve from 0.24988
# 345/345 [==============================] - 417s 1s/step - loss: 0.3305 - accuracy: 0.8592 - val_loss: 0.2773 - val_accuracy: 0.8950 - lr: 1.0000e-04
# Epoch 4/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8605
# Epoch 4: val_loss improved from 0.24988 to 0.23860, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 419s 1s/step - loss: 0.3277 - accuracy: 0.8605 - val_loss: 0.2386 - val_accuracy: 0.9088 - lr: 1.0000e-04
# Epoch 5/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8687
# Epoch 5: val_loss improved from 0.23860 to 0.23180, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 416s 1s/step - loss: 0.3137 - accuracy: 0.8687 - val_loss: 0.2318 - val_accuracy: 0.9078 - lr: 1.0000e-04
# Epoch 6/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8687
# Epoch 6: val_loss improved from 0.23180 to 0.22671, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 414s 1s/step - loss: 0.3119 - accuracy: 0.8687 - val_loss: 0.2267 - val_accuracy: 0.9132 - lr: 1.0000e-04
# Epoch 7/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8693
# Epoch 7: val_loss improved from 0.22671 to 0.21240, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 414s 1s/step - loss: 0.3086 - accuracy: 0.8693 - val_loss: 0.2124 - val_accuracy: 0.9214 - lr: 1.0000e-04
# Epoch 8/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3051 - accuracy: 0.8710
# Epoch 8: val_loss did not improve from 0.21240
# 345/345 [==============================] - 412s 1s/step - loss: 0.3051 - accuracy: 0.8710 - val_loss: 0.2444 - val_accuracy: 0.9052 - lr: 1.0000e-04
# Epoch 9/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3035 - accuracy: 0.8705
# Epoch 9: val_loss did not improve from 0.21240
# 345/345 [==============================] - 410s 1s/step - loss: 0.3035 - accuracy: 0.8705 - val_loss: 0.2238 - val_accuracy: 0.9132 - lr: 1.0000e-04
# Epoch 10/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.8731
# Epoch 10: val_loss did not improve from 0.21240
# 345/345 [==============================] - 410s 1s/step - loss: 0.2999 - accuracy: 0.8731 - val_loss: 0.2132 - val_accuracy: 0.9175 - lr: 1.0000e-04
# Epoch 11/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8758
# Epoch 11: val_loss did not improve from 0.21240
# 345/345 [==============================] - 410s 1s/step - loss: 0.2937 - accuracy: 0.8758 - val_loss: 0.2301 - val_accuracy: 0.9088 - lr: 1.0000e-04
# Epoch 12/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2980 - accuracy: 0.8767
# Epoch 12: val_loss did not improve from 0.21240
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 345/345 [==============================] - 410s 1s/step - loss: 0.2980 - accuracy: 0.8767 - val_loss: 0.2424 - val_accuracy: 0.9083 - lr: 1.0000e-04
# Epoch 13/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8768
# Epoch 13: val_loss did not improve from 0.21240
# 345/345 [==============================] - 411s 1s/step - loss: 0.2933 - accuracy: 0.8768 - val_loss: 0.2191 - val_accuracy: 0.9178 - lr: 5.0000e-05
# Epoch 14/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.8790
# Epoch 14: val_loss improved from 0.21240 to 0.21073, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 412s 1s/step - loss: 0.2872 - accuracy: 0.8790 - val_loss: 0.2107 - val_accuracy: 0.9182 - lr: 5.0000e-05
# Epoch 15/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8811
# Epoch 15: val_loss did not improve from 0.21073
# 345/345 [==============================] - 414s 1s/step - loss: 0.2861 - accuracy: 0.8811 - val_loss: 0.2414 - val_accuracy: 0.9049 - lr: 5.0000e-05
# Epoch 16/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8822
# Epoch 16: val_loss did not improve from 0.21073
# 345/345 [==============================] - 413s 1s/step - loss: 0.2859 - accuracy: 0.8822 - val_loss: 0.2163 - val_accuracy: 0.9151 - lr: 5.0000e-05
# Epoch 17/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.8822
# Epoch 17: val_loss did not improve from 0.21073
# 345/345 [==============================] - 413s 1s/step - loss: 0.2806 - accuracy: 0.8822 - val_loss: 0.2301 - val_accuracy: 0.9088 - lr: 5.0000e-05
# Epoch 18/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8812
# Epoch 18: val_loss did not improve from 0.21073
# 345/345 [==============================] - 413s 1s/step - loss: 0.2837 - accuracy: 0.8812 - val_loss: 0.2141 - val_accuracy: 0.9161 - lr: 5.0000e-05
# Epoch 19/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8819
# Epoch 19: val_loss did not improve from 0.21073
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 345/345 [==============================] - 413s 1s/step - loss: 0.2819 - accuracy: 0.8819 - val_loss: 0.2145 - val_accuracy: 0.9168 - lr: 5.0000e-05
# Epoch 20/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8846
# Epoch 20: val_loss did not improve from 0.21073
# 345/345 [==============================] - 412s 1s/step - loss: 0.2805 - accuracy: 0.8846 - val_loss: 0.2174 - val_accuracy: 0.9161 - lr: 2.5000e-05
# Epoch 21/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.8840
# Epoch 21: val_loss did not improve from 0.21073
# 345/345 [==============================] - 415s 1s/step - loss: 0.2768 - accuracy: 0.8840 - val_loss: 0.2196 - val_accuracy: 0.9134 - lr: 2.5000e-05
# Epoch 22/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.8814
# Epoch 22: val_loss improved from 0.21073 to 0.20670, saving model to best_gmm_saliency_efficientnet\best_EfficientNetV2_model.keras
# 345/345 [==============================] - 419s 1s/step - loss: 0.2812 - accuracy: 0.8814 - val_loss: 0.2067 - val_accuracy: 0.9221 - lr: 2.5000e-05
# Epoch 23/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.8851
# Epoch 23: val_loss did not improve from 0.20670
# 345/345 [==============================] - 418s 1s/step - loss: 0.2747 - accuracy: 0.8851 - val_loss: 0.2212 - val_accuracy: 0.9156 - lr: 2.5000e-05
# Epoch 24/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8839
# Epoch 24: val_loss did not improve from 0.20670
# 345/345 [==============================] - 416s 1s/step - loss: 0.2754 - accuracy: 0.8839 - val_loss: 0.2122 - val_accuracy: 0.9199 - lr: 2.5000e-05
# Epoch 25/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8864
# Epoch 25: val_loss did not improve from 0.20670
# 345/345 [==============================] - 418s 1s/step - loss: 0.2746 - accuracy: 0.8864 - val_loss: 0.2100 - val_accuracy: 0.9204 - lr: 2.5000e-05
# Epoch 26/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.8863
# Epoch 26: val_loss did not improve from 0.20670
# 345/345 [==============================] - 416s 1s/step - loss: 0.2768 - accuracy: 0.8863 - val_loss: 0.2255 - val_accuracy: 0.9124 - lr: 2.5000e-05
# Epoch 27/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8832
# Epoch 27: val_loss did not improve from 0.20670
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 345/345 [==============================] - 417s 1s/step - loss: 0.2798 - accuracy: 0.8832 - val_loss: 0.2121 - val_accuracy: 0.9182 - lr: 2.5000e-05
# Epoch 28/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.8851
# Epoch 28: val_loss did not improve from 0.20670
# 345/345 [==============================] - 415s 1s/step - loss: 0.2753 - accuracy: 0.8851 - val_loss: 0.2077 - val_accuracy: 0.9185 - lr: 1.2500e-05
# Epoch 29/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8871
# Epoch 29: val_loss did not improve from 0.20670
# 345/345 [==============================] - 409s 1s/step - loss: 0.2739 - accuracy: 0.8871 - val_loss: 0.2128 - val_accuracy: 0.9165 - lr: 1.2500e-05
# Epoch 30/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.8875
# Epoch 30: val_loss did not improve from 0.20670
# 345/345 [==============================] - 409s 1s/step - loss: 0.2705 - accuracy: 0.8875 - val_loss: 0.2135 - val_accuracy: 0.9180 - lr: 1.2500e-05
# Epoch 31/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.8851
# Epoch 31: val_loss did not improve from 0.20670
# 345/345 [==============================] - 408s 1s/step - loss: 0.2727 - accuracy: 0.8851 - val_loss: 0.2093 - val_accuracy: 0.9178 - lr: 1.2500e-05
# Epoch 32/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.8888
# Epoch 32: val_loss did not improve from 0.20670
# Restoring model weights from the end of the best epoch: 22.
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 345/345 [==============================] - 414s 1s/step - loss: 0.2714 - accuracy: 0.8888 - val_loss: 0.2117 - val_accuracy: 0.9170 - lr: 1.2500e-05
# Epoch 32: early stopping

# %%
# Paths for saving results and plots
output_csv_path_EfficientNetV2 = 'best_gmm_saliency_efficientnet/efficientnet_gmm_saliency_efficientnet_test_results.csv'
roc_curve_path_EfficientNetV2 = 'best_gmm_saliency_efficientnet/efficientnet_gmm_saliency_efficientnet_roc_curve.png'

# Get true labels and predictions
y_true = test_generator.classes
y_pred_prob = EfficientNetV2_model.predict(test_generator)
y_pred = np.where(y_pred_prob > 0.5, 1, 0)

# Get filenames
filenames = test_generator.filenames

# Create DataFrame for results
results_df = pd.DataFrame({
    'Nama File': filenames,
    'Label Asli': y_true,
    'Prediksi': y_pred.flatten()
})

# Calculate Metrics
mcc_mobilenet = matthews_corrcoef(y_true, y_pred)
auc_roc_mobilenet = roc_auc_score(y_true, y_pred_prob)
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# Print Metrics
print(f"EfficientNetV2 Metrics:\n"
      f"MCC: {mcc_mobilenet}\n"
      f"AUC-ROC: {auc_roc_mobilenet}\n"
      f"Accuracy: {accuracy}\n"
      f"Precision: {precision}\n"
      f"Recall: {recall}\n"
      f"F1-Score: {f1}")

# Append metrics to DataFrame for the entire dataset
results_df['MCC'] = [mcc_mobilenet] * len(results_df)
results_df['AUC-ROC'] = [auc_roc_mobilenet] * len(results_df)
results_df['Accuracy'] = [accuracy] * len(results_df)
results_df['Precision'] = [precision] * len(results_df)
results_df['Recall'] = [recall] * len(results_df)
results_df['F1-Score'] = [f1] * len(results_df)

# Save the results to CSV
results_df.to_csv(output_csv_path_EfficientNetV2, index=False)
print(f"Hasil prediksi EfficientNetV2 disimpan di {output_csv_path_EfficientNetV2}")

# Plot and save ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)  # Use probabilities directly
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) EfficientNet')
plt.legend(loc='lower right')
plt.savefig(roc_curve_path_EfficientNetV2)
plt.close()
# Out:
# 22/22 [==============================] - 23s 972ms/step
# EfficientNetV2 Metrics:
# MCC: 0.8499368282688923
# AUC-ROC: 0.9789349955026215
# Accuracy: 0.9238026124818578
# Precision: 0.8945945945945946
# Recall: 0.9608127721335269
# F1-Score: 0.926522043386984
# Hasil prediksi EfficientNetV2 disimpan di best_gmm_saliency_efficientnet/efficientnet_gmm_saliency_efficientnet_test_results.csv

# %%
import matplotlib.pyplot as plt

# Ambil data dari history
history = history_EfficientNetV2.history
epochs = range(1, len(history['loss']) + 1)

# Buat plot
plt.figure(figsize=(12, 6))

# Plot Loss dan Validation Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, history['loss'], label='Training Loss')
plt.plot(epochs, history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss EfficientNet')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy dan Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, history['accuracy'], label='Training Accuracy')
plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy EfficientNet GMM with Saliency')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Simpan plot
plt.tight_layout()
plt.savefig('training_validation_metrics.png', dpi=300)  # Simpan gambar dengan nama file dan resolusi
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# Hitung confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Tampilkan confusion matrix dengan visualisasi
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
